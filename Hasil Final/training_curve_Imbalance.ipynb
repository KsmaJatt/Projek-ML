# %%
# Data CNN dari log training
cnn_train_acc = [0.6027, 0.8029, 0.8592, 0.8811, 0.8953, 0.9077, 0.9173, 0.9244, 0.9373, 0.9406, 0.9714, 0.9764]
cnn_val_acc   = [0.7591, 0.7162, 0.8326, 0.8891, 0.8001, 0.8418, 0.8906, 0.8746, 0.8833, 0.8896, 0.8952, 0.8734]
cnn_train_loss = [1.2386, 0.5916, 0.4157, 0.3452, 0.3089, 0.2649, 0.2446, 0.2180, 0.1878, 0.1744, 0.0849, 0.0676]
cnn_val_loss   = [0.7169, 0.9569, 0.4660, 0.3436, 0.7134, 0.6088, 0.3085, 0.4018, 0.3678, 0.3744, 0.4001, 0.5154]

# Data EfficientNetB0 dari log training
phase1_train_acc = [0.7630, 0.8656, 0.8850, 0.8931, 0.9040, 0.9057, 0.9112, 0.9170, 0.9201, 0.9209]
phase1_val_acc   = [0.8785, 0.9270, 0.9231, 0.9333, 0.9369, 0.9410, 0.9464, 0.9360, 0.9384, 0.9372]
phase1_train_loss = [0.7384, 0.4001, 0.3378, 0.3071, 0.2858, 0.2687, 0.2585, 0.2445, 0.2321, 0.2306]
phase1_val_loss   = [0.3529, 0.2378, 0.2317, 0.1983, 0.1798, 0.1774, 0.1604, 0.1851, 0.1818, 0.1769]

phase2_train_acc = [0.9034, 0.9448, 0.9566, 0.9668, 0.9683, 0.9754, 0.9790, 0.9804, 0.9833, 0.9847]
phase2_val_acc   = [0.9634, 0.9704, 0.9721, 0.9745, 0.9803, 0.9774, 0.9823, 0.9770, 0.9816, 0.9879]
phase2_train_loss = [0.2837, 0.1586, 0.1266, 0.0972, 0.0901, 0.0730, 0.0608, 0.0565, 0.0492, 0.0457]
phase2_val_loss   = [0.1113, 0.0890, 0.0799, 0.0737, 0.0573, 0.0628, 0.0529, 0.0631, 0.0544, 0.0404]

eff_train_acc  = phase1_train_acc + phase2_train_acc
eff_val_acc    = phase1_val_acc   + phase2_val_acc
eff_train_loss = phase1_train_loss + phase2_train_loss
eff_val_loss   = phase1_val_loss   + phase2_val_loss

# Data XGBoost dari log training
xgb_rounds     = [0, 50, 100, 150, 199]
xgb_val_loss   = [2.10382, 0.16710, 0.09017, 0.07660, 0.07201]

# %%
import matplotlib.pyplot as plt

# Plot CNN
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
cnn_epochs = list(range(1, len(cnn_train_acc) + 1))

axes[0].plot(cnn_epochs, cnn_train_acc, label='Train', marker='o', markersize=4)
axes[0].plot(cnn_epochs, cnn_val_acc, label='Val', marker='o', markersize=4)
axes[0].set_title('CNN Sederhana Accuracy')
axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Accuracy')
axes[0].legend(); axes[0].grid(True, alpha=0.3)

axes[1].plot(cnn_epochs, cnn_train_loss, label='Train', marker='o', markersize=4)
axes[1].plot(cnn_val_loss, label='Val', marker='o', markersize=4)
axes[1].set_title('CNN Sederhana Loss')
axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Loss')
axes[1].legend(); axes[1].grid(True, alpha=0.3)

plt.suptitle('Training Curve CNN Sederhana', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Plot EfficientNetB0
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
eff_epochs = list(range(1, len(eff_train_acc) + 1))

axes[0].plot(eff_epochs, eff_train_acc, label='Train', marker='o', markersize=4)
axes[0].plot(eff_epochs, eff_val_acc, label='Val', marker='o', markersize=4)
axes[0].axvline(x=10.5, color='red', linestyle='--', label='Fine-tune start')
axes[0].set_title('EfficientNetB0 Accuracy')
axes[0].set_xlabel('Epoch'); axes[0].set_ylabel('Accuracy')
axes[0].legend(); axes[0].grid(True, alpha=0.3)

axes[1].plot(eff_epochs, eff_train_loss, label='Train', marker='o', markersize=4)
axes[1].plot(eff_epochs, eff_val_loss, label='Val', marker='o', markersize=4)
axes[1].axvline(x=10.5, color='red', linestyle='--', label='Fine-tune start')
axes[1].set_title('EfficientNetB0 — Loss')
axes[1].set_xlabel('Epoch'); axes[1].set_ylabel('Loss')
axes[1].legend(); axes[1].grid(True, alpha=0.3)

plt.suptitle('Training Curve EfficientNetB0 (Phase 1 + Fine-tune)', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Plot XGBoost
plt.figure(figsize=(7, 5))
plt.plot(xgb_rounds, xgb_val_loss, label='Val Log Loss', marker='o',
         markersize=6, color='#C44E52')
plt.title('Training Curve Hybrid XGBoost')
plt.xlabel('Boosting Round')
plt.ylabel('Log Loss')
plt.legend(); plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
